# %% [markdown]
# ## Trim Polity

# %%
import pandas as pd

# %%
pol = pd.read_csv("../Data/PolityIV/p4v2018.csv")

# %%
pol.columns
# Out:
# Index(['cyear', 'ccode', 'scode', 'country', 'year', 'flag', 'fragment',
#        'democ', 'autoc', 'polity', 'polity2', 'durable', 'xrreg', 'xrcomp',
#        'xropen', 'xconst', 'parreg', 'parcomp', 'exrec', 'exconst', 'polcomp',
#        'prior', 'emonth', 'eday', 'eyear', 'eprec', 'interim', 'bmonth',
#        'bday', 'byear', 'bprec', 'post', 'change', 'd4', 'sf', 'regtrans'],
#       dtype='object')

# %%
pol_trim = pol.drop(columns=['cyear', 'scode', 'country', 'flag', 'prior', 'emonth', 'eday', 'eyear', 'eprec', 'bmonth', 'bday', 'byear', 'bprec', 'post'])
pol_trim = pol_trim[pol_trim['year'] > 1945]
pol_trim
# Out:
#        ccode  year  fragment  democ  autoc  polity  polity2  durable  xrreg  \
# 146        2  1946       NaN     10      0      10     10.0    137.0      3
# 147        2  1947       NaN     10      0      10     10.0    138.0      3
# 148        2  1948       NaN     10      0      10     10.0    139.0      3
# 149        2  1949       NaN     10      0      10     10.0    140.0      3
# 150        2  1950       NaN     10      0      10     10.0    141.0      3
# ...      ...   ...       ...    ...    ...     ...      ...      ...    ...
# 17557    950  2014       0.0      3      1       2      2.0      0.0      2
# 17558    950  2015       0.0      3      1       2      2.0      1.0      2
# 17559    950  2016       0.0      3      1       2      2.0      2.0      2
# 17560    950  2017       0.0      3      1       2      2.0      3.0      2
# 17561    950  2018       0.0      4      0       4      2.0      4.0      2
#
# ...

# %%
pol_trim.to_csv("../Data/FINAL/polity.csv", index=False, encoding='utf-8')
